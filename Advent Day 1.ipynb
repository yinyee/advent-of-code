# %%
# open file for reading

f = open('1_input', 'r')

# %%
# read file into an array of lines
# doing it this way to avoid appending a newline character to the end of each line

lines = f.read().splitlines()

# %%
# there is only line and it has 2040 characters

print("There are {} line(s)".format(len(lines)))
line = lines[0]
print("There are {} characters in line".format(len(line)))
# Out:
# There are 1 line(s)
# There are 2040 characters in line

# %%
# print out the values at each position
# array index always starts at 0

for i in range (len(line)):
    print("{}: {}".format(i, input[i]))
# Out:
# 0: 8
# 1: 9
# 2: 2
# 3: 1
# 4: 9
# 5: 5
# 6: 9
# 7: 6
# 8: 9
# 9: 9
# 10: 9
# 11: 1
# 12: 7
# 13: 3
# 14: 5
# 15: 8
# 16: 3
# 17: 7
# 18: 9
# 19: 1
# 20: 5
# 21: 2
# 22: 7
# 23: 3
# 24: 8
# 25: 6
# 26: 8
# 27: 7
# 28: 2
# 29: 9
# 30: 5
# 31: 4
# 32: 8
# 33: 6
# 34: 9
# 35: 4
# 36: 2
# 37: 3
# 38: 7
# 39: 9
# 40: 6
# 41: 7
# 42: 4
# 43: 9
# 44: 5
# 45: 1
# 46: 1
# 47: 5
# 48: 4
# 49: 1
# 50: 2
# 51: 3
# 52: 9
# 53: 9
# 54: 3
# 55: 7
# 56: 3
# 57: 1
# 58: 9
# 59: 4
# 60: 5
# 61: 6
# 62: 2
# 63: 5
# 64: 2
# 65: 6
# 66: 9
# 67: 4
# 68: 7
# 69: 5
# 70: 8
# 71: 5
# 72: 3
# 73: 3
# 74: 7
# 75: 2
# 76: 3
# 77: 3
# 78: 7
# 79: 9
# 80: 3
# 81: 5
# 82: 6
# 83: 8
# 84: 2
# 85: 7
# 86: 8
# 87: 2
# 88: 6
# 89: 5
# 90: 2
# 91: 7
# 92: 9
# 93: 1
# 94: 9
# 95: 9
# 96: 8
# 97: 8
# 98: 3
# 99: 1
# 100: 9
# 101: 7
# 102: 1
# 103: 6
# 104: 7
# 105: 6
# 106: 3
# 107: 4
# 108: 7
# 109: 9
# 110: 1
# 111: 2
# 112: 9
# 113: 3
# 114: 1
# 115: 7
# 116: 7
# 117: 9
# 118: 8
# 119: 6
# 120: 1
# 121: 5
# 122: 2
# ...

# %%
# append the first character to the end of the line
# according to the instructions, the input loops back onto itself

line += line[0]
print("There are now {} characters in line".format(len(line)))
# Out:
# There are now 2041 characters in line

# %%
# print out the first and the last few characters to compare

print("{}: {}".format(0, line[0]))

print(".\n.\n.")

for i in range (2037, len(line)):
    print("{}: {}".format(i, line[i]))
# Out:
# 0: 8
# .
# .
# .
# 2037: 8
# 2038: 7
# 2039: 8
# 2040: 8

# %% [markdown]
# Through manual verification, we know that the first few results that meet the condition are:
# ```
#   8: 9
#   9: 9
#   45: 1
# ```
# and so on...

# %%
# create an empty array to store the values that match the condition

keep = []

for i in range(len(line)-1):
    if line[i] == line[i+1]:
        keep.append(line[i])

# %%
# convert all the strings into integers

keep = [int(i) for i in keep]

# %%
# finally print out the sum of the values in the array

print(sum(keep))
# Out:
# 1047
